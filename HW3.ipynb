# %%
import pandas as pd
import numpy as np

# %%
import math as m

# %%
df_FAQ = pd.read_csv(r"C:\Users\gurzh\Downloads\survey_results_schema.csv")
df_FAQ.head()
# Out:
#       qid       qname                                           question  \
# 0    QID2  MainBranch  Which of the following options best describes ...
# 1  QID127         Age                                 What is your age?*
# 2  QID296  Employment  Which of the following best describes your cur...
# 3  QID308  RemoteWork  Which best describes your current work situation?
# 4  QID341       Check  Just checking to make sure you are paying atte...
#
#   force_resp type selector
# 0       True   MC     SAVR
# 1       True   MC     SAVR
# 2       True   MC     MAVR
# 3      False   MC     SAVR
# 4       True   MC     SAVR

# %%
df = pd.read_csv(r'C:\Users\gurzh\Downloads\survey_results_public.csv')

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
df['ResponseId'].notna().count()  # Task1
# Out:
# np.int64(65437)

# %%
df['ResponseId'].notna().sum() # Task1
# Out:
# np.int64(65437)

# %%
responded_all_questions = df.dropna(axis=0)  #Task2
a = responded_all_questions.shape[0]
print(f'There are {a} respondents answer all question')
# Out:
# There are 0 respondents answer all question

# %%
new_df = df.agg({'WorkExp': ['mean', 'median']}) #Task3
new_df
# Out:
#           WorkExp
# mean    11.466957
# median   9.000000

# %%
print(f'There are {df[df['RemoteWork'].isin(['Remote'])].shape[0]} respondents work Remote') #Task4
# Out:
# There are 20831 respondents work Remote

# %%
work_with_Python = df[df['LanguageHaveWorkedWith'].str.contains('Python', case=False, na=False)].shape[0] #Task5
total = df.shape[0] 
percent_work_Python = (work_with_Python / total)*100
print(f'{percent_work_Python} % are coding using Python')
# Out:
# 47.0605315035836 % are coding using Python

# %%
learnOnline = df[df['LearnCode'].str.contains('online', case=False, na=False)].shape[0] #Task6
print(f'There are {learnOnline} respondents lern code Online')
# Out:
# There are 54061 respondents lern code Online

# %%
work_with_Python = df[df['LanguageHaveWorkedWith'].str.contains('Python', case=False, na=False)] #Task7
work_with_Python.groupby('Country').agg({'ConvertedCompYearly': ['mean', 'median']})
# Out:
#                                      ConvertedCompYearly
#                                                     mean    median
# Country
# Afghanistan                                  4543.000000    4768.5
# Albania                                     56295.000000   56295.0
# Algeria                                      9053.285714    6230.0
# Andorra                                    193331.000000  193331.0
# Angola                                          6.000000       6.0
# ...                                                  ...       ...
# Venezuela, Bolivarian Republic of...        21500.000000    7100.0
# Viet Nam                                    14014.562500   10180.0
# Yemen                                       10297.333333    5333.0
# Zambia                                      28123.666667   22803.0
# Zimbabwe                                    37500.000000   18000.0
#
# [173 rows x 2 columns]

# %%
work_with_Python = df[df['LanguageHaveWorkedWith'].str.contains('Python', case=False, na=False)] #Task7 with renaming Columns
work_with_Python.groupby('Country').agg(AvgComp=('ConvertedCompYearly', 'mean'), MedianComp=('ConvertedCompYearly', 'median'))
# Out:
#                                             AvgComp  MedianComp
# Country
# Afghanistan                             4543.000000      4768.5
# Albania                                56295.000000     56295.0
# Algeria                                 9053.285714      6230.0
# Andorra                               193331.000000    193331.0
# Angola                                     6.000000         6.0
# ...                                             ...         ...
# Venezuela, Bolivarian Republic of...   21500.000000      7100.0
# Viet Nam                               14014.562500     10180.0
# Yemen                                  10297.333333      5333.0
# Zambia                                 28123.666667     22803.0
# Zimbabwe                               37500.000000     18000.0
#
# [173 rows x 2 columns]

# %%
a =df.sort_values(by='ConvertedCompYearly', ascending=False).head()   #Task 8
a['EdLevel'].unique()
# Out:
# array(['Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Professional degree (JD, MD, Ph.D, Ed.D, etc.)'], dtype=object)

# %%
work_with_Python = df[df['LanguageHaveWorkedWith'].str.contains('Python', case=False, na=False)]  #Bonus Task1 - 1st option
number = work_with_Python.shape[0]
new_df=work_with_Python.groupby('Age').size()
new_df['Perc_Python'] = new_df.transform(lambda x: x/number)
new_df
# Out:
# Age
# 18-24 years old                                                    7884
# 25-34 years old                                                   10945
# 35-44 years old                                                    6204
# 45-54 years old                                                    2619
# 55-64 years old                                                    1041
# 65 years or older                                                   290
# Prefer not to say                                                   146
# Under 18 years old                                                 1666
# Perc_Python           Age
# 18-24 years old       0.256016
# 25-34 years...
# dtype: object

# %%
work_with_Python = df[df['LanguageHaveWorkedWith'].str.contains('Python', case=False, na=False)]  #Bonus Task1 - 2nd option
number = work_with_Python.shape[0]
a=work_with_Python.groupby('Age')['ResponseId'].count()
a['Perc_Python'] = a.transform(lambda x: x/number)
a
# Out:
# Age
# 18-24 years old                                                    7884
# 25-34 years old                                                   10945
# 35-44 years old                                                    6204
# 45-54 years old                                                    2619
# 55-64 years old                                                    1041
# 65 years or older                                                   290
# Prefer not to say                                                   146
# Under 18 years old                                                 1666
# Perc_Python           Age
# 18-24 years old       0.256016
# 25-34 years...
# Name: ResponseId, dtype: object

# %%
df1 = df[(df['ConvertedCompYearly'] > df['ConvertedCompYearly'].quantile(0.75)) & (df['RemoteWork'].isin(['Remote']))]  #Bonus Task 2
df1
# Out:
#        ResponseId                      MainBranch              Age  \
# 389           390  I am a developer by profession  25-34 years old
# 395           396  I am a developer by profession  45-54 years old
# 398           399  I am a developer by profession  45-54 years old
# 414           415  I am a developer by profession  45-54 years old
# 416           417  I am a developer by profession  35-44 years old
# ...           ...                             ...              ...
# 41141       41142  I am a developer by profession  25-34 years old
# 41142       41143  I am a developer by profession  45-54 years old
# 41149       41150  I am a developer by profession  25-34 years old
# 41165       41166  I am a developer by profession  55-64 years old
# 41185       41186  I am a developer by profession  35-44 years old
#
#                                               Employment RemoteWork   Check  \
# 389               Employed, full-time;Student, part-time     Remote  Apples
# ...

# %%
df1['Industry'].value_counts()
# Out:
# Industry
# Software Development                          768
# Other:                                        239
# Healthcare                                    156
# Fintech                                       156
# Internet, Telecomm or Information Services    145
# Retail and Consumer Services                  106
# Media & Advertising Services                  103
# Computer Systems Design and Services           69
# Banking/Financial Services                     69
# Government                                     69
# Transportation, or Supply Chain                67
# Insurance                                      50
# Manufacturing                                  48
# Higher Education                               42
# Energy                                         36
# Name: count, dtype: int64
